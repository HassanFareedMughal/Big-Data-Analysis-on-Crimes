# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv(r"D:\UNIVERSITY\3rd Semester\DSA\DSA Project\archive (1)\pakistan-crime-data.csv")

# %%
df
# Out:
#     Year                Offence  Punjab  Sindh      KP  Balochistan  \
# 0   2012                 Murder    6128   3726    2958          711
# 1   2012      Attempt to Murder    7641   3732    2892          583
# 2   2012  Kidnapping /Abduction   15699   3077    1052          386
# 3   2012                Dacoity    2715   1341      60           98
# 4   2012                Robbery   12181   4320     134          160
# 5   2012               Burglary   14740   1680     500          117
# 6   2012           Cattle Theft    8115    630     118           77
# 7   2012            Other Theft   34719   2976     717          332
# 8   2012                 Others  292665  57206  139344         5745
# 9   2012   TOTAL RECORDED CRIME  394603  78688  147775         8209
# 10  2013                 Murder    5969   3854    3163          639
# 11  2013      Attempt to Murder    6935   3568    3146          482
# 12  2013  Kidnapping /Abduction   14527   3149    1137          304
# ...

# %%
murders = df.loc[0:2]

# %%
murders
# Out:
#    Year                Offence  Punjab  Sindh    KP  Balochistan  Islamabad  \
# 0  2012                 Murder    6128   3726  2958          711        120
# 1  2012      Attempt to Murder    7641   3732  2892          583        146
# 2  2012  Kidnapping /Abduction   15699   3077  1052          386         70
#
#    Railways  G.B  AJK  Pakistan
# 0         6  102   95     13846
# 1         9  163  172     15338
# 2         6   32  288     20610

# %%
print(murders)
# Out:
#    Year                Offence  Punjab  Sindh    KP  Balochistan  Islamabad  \
# 0  2012                 Murder    6128   3726  2958          711        120
# 1  2012      Attempt to Murder    7641   3732  2892          583        146
# 2  2012  Kidnapping /Abduction   15699   3077  1052          386         70
#
#    Railways  G.B  AJK  Pakistan
# 0         6  102   95     13846
# 1         9  163  172     15338
# 2         6   32  288     20610

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Year         60 non-null     int64
#  1   Offence      60 non-null     object
#  2   Punjab       60 non-null     int64
#  3   Sindh        60 non-null     int64
#  4   KP           60 non-null     int64
#  5   Balochistan  60 non-null     int64
#  6   Islamabad    60 non-null     int64
#  7   Railways     60 non-null     int64
#  8   G.B          60 non-null     int64
#  9   AJK          60 non-null     int64
#  10  Pakistan     60 non-null     int64
# dtypes: int64(10), object(1)
# memory usage: 5.3+ KB

# %%
df.head()
# Out:
#    Year                Offence  Punjab  Sindh    KP  Balochistan  Islamabad  \
# 0  2012                 Murder    6128   3726  2958          711        120
# 1  2012      Attempt to Murder    7641   3732  2892          583        146
# 2  2012  Kidnapping /Abduction   15699   3077  1052          386         70
# 3  2012                Dacoity    2715   1341    60           98         22
# 4  2012                Robbery   12181   4320   134          160        177
#
#    Railways  G.B  AJK  Pakistan
# 0         6  102   95     13846
# 1         9  163  172     15338
# 2         6   32  288     20610
# 3         1    8   12      4257
# 4         5   26   78     17081

# %%
df.shape
# Out:
# (60, 11)

# %%
df.columns
# Out:
# Index(['Year', 'Offence', 'Punjab', 'Sindh', 'KP', 'Balochistan', 'Islamabad',
#        'Railways', 'G.B', 'AJK', 'Pakistan'],
#       dtype='object')

# %%
df.describe()
# Out:
#               Year         Punjab         Sindh             KP  Balochistan  \
# count    60.000000      60.000000     60.000000      60.000000    60.000000
# mean   2014.500000   79055.900000  14763.366667   31113.833333  1758.166667
# std       1.722237  138782.467265  25794.011521   60948.397625  3099.910568
# min    2012.000000     602.000000    383.000000      45.000000    30.000000
# 25%    2013.000000    5924.000000   1403.500000     204.250000   151.250000
# 50%    2014.500000   12395.000000   2662.500000    1115.000000   263.000000
# 75%    2016.000000   30760.000000   3762.500000    3150.250000   591.000000
# max    2017.000000  408148.000000  78688.000000  180830.000000  9492.000000
#
#          Islamabad     Railways          G.B          AJK       Pakistan
# count    60.000000    60.000000    60.000000    60.000000      60.000000
# mean   1517.733333   347.833333   308.466667  1199.900000  130065.200000
# ...

# %%
ax = sns.countplot(x = 'Punjab', data = df)
for bars in ax.containers:
    ax.bar_label(bars)

# %%
violence = df.groupby(['Punjab'], as_index = False)['Year'].sum().sort_values(by = 'Year', ascending = False)
sns.barplot(x = 'Punjab', y = 'Year', data = violence)
# Out:
# <AxesSubplot:xlabel='Punjab', ylabel='Year'>

# %%
data = pd.DataFrame({
    'Region': ['Punjab', 'Sindh', 'Balochistan'],
    'Metric': ['Murders', 'Murders', 'Murders'],
    'Value': [100, 150, 50]
})

murder_data = data[data['Metric'] == 'Murders']

colors = ['blue', 'green', 'red']

plt.bar(murder_data['Region'], murder_data['Value'], color=colors)

plt.xlabel('Region')
plt.ylabel('Number of Murders')
plt.title('Murders in Different Regions')
plt.show()

# %%
data = pd.DataFrame({
    'Region': ['Punjab', 'Sindh', 'Balochistan'],
    'Metric': ['Murders', 'Murders', 'Murders'],
    'Value': [100, 150, 50]
})

murder_data = data[data['Metric'] == 'Murders']

colors = ['blue', 'green', 'red']

plt.bar(murder_data['Region'], murder_data['Value'], color=colors)

plt.xlabel('Region')
plt.ylabel('Number of Murders')
plt.title('Murders in Different Regions')
plt.show()

# %%
unique_years = df['Year'].unique()

for year in unique_years:
    year_data = df[df['Year'] == year]

    murders = year_data[year_data['Offence'] == 'Murder']

    # Plot the data
    regions = ['Punjab', 'Sindh', 'KP', 'Balochistan', 'Islamabad', 'Railways', 'G.B', 'AJK']
    murder_cases = murders[regions].iloc[0]

    plt.figure(figsize=(10, 6))
    plt.bar(regions, murder_cases)
    plt.title(f'Number of Murders in Different Regions of Pakistan ({year})')
    plt.xlabel('Regions')
    plt.ylabel('Number of Murders')

    for i, v in enumerate(murder_cases):
        plt.text(i, v, str(v), ha='center', va='bottom')

    plt.show()
